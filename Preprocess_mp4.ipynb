# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab.patches import cv2_imshow

# %%
image_path = "drive/My Drive/images/"

# %%
import cv2
import os
print(cv2.__version__)
vidcap = cv2.VideoCapture(image_path+"HxH25.mp4")
vidcap.read()
# Out:
# 4.1.2
# (True, array([[[ 47,  36,  54],
#          [ 61,  50,  68],
#          [ 62,  51,  69],
#          ...,
#          [148, 125, 150],
#          [151, 128, 153],
#          [101,  78, 103]],
#
#         [[ 47,  36,  54],
#          [ 61,  50,  68],
#          [ 62,  51,  69],
#          ...,
#          [148, 125, 150],
#          [151, 128, 153],
#          [101,  78, 103]],
#
#         [[ 47,  36,  54],
#          [ 61,  50,  68],
#          [ 62,  51,  69],
#          ...,
#          [148, 125, 150],
#          [151, 128, 153],
#          [101,  78, 103]],
#
#         ...,
#
#         [[131, 106, 124],
#          [186, 161, 179],
#          [184, 159, 177],
#          ...,
#          [ 85,  86,  96],
#          [ 84,  85,  95],
#          [ 63,  64,  74]],
#
#         [[130, 105, 123],
#          [186, 161, 179],
#          [184, 159, 177],
#          ...,
#          [ 85,  86,  96],
#          [ 84,  85,  95],
#          [ 63,  64,  74]],
#
#         [[130, 105, 123],
#          [186, 161, 179],
#          [184, 159, 177],
#          ...,
#          [ 85,  86,  96],
#          [ 84,  85,  95],
#          [ 63,  64,  74]]], dtype=uint8))

# %%
vid_path = "drive/My Drive/HxH25_frames/"

# %%
success,image = vidcap.read()
count = 0
success = True
while success:
    vidcap.set(cv2.CAP_PROP_POS_MSEC,(count*3000))
    success,image = vidcap.read()
    print ('Read a new frame: ', success)
    cv2.imwrite(vid_path+"frame25_%d.jpg" % count, image)     # save frame as JPEG file
    count += 1
    print(count)
    #cv2_imshow(image)
# Out:
# Read a new frame:  True
# 1
# Read a new frame:  True
# 2
# Read a new frame:  True
# 3
# Read a new frame:  True
# 4
# Read a new frame:  True
# 5
# Read a new frame:  True
# 6
# Read a new frame:  True
# 7
# Read a new frame:  True
# 8
# Read a new frame:  True
# 9
# Read a new frame:  True
# 10
# Read a new frame:  True
# 11
# Read a new frame:  True
# 12
# Read a new frame:  True
# 13
# Read a new frame:  True
# 14
# Read a new frame:  True
# 15
# Read a new frame:  True
# 16
# Read a new frame:  True
# 17
# Read a new frame:  True
# 18
# Read a new frame:  True
# 19
# Read a new frame:  True
# 20
# Read a new frame:  True
# 21
# Read a new frame:  True
# 22
# Read a new frame:  True
# 23
# Read a new frame:  True
# 24
# Read a new frame:  True
# 25
# Read a new frame:  True
# 26
# Read a new frame:  True
# 27
# Read a new frame:  True
# 28
# Read a new frame:  True
# 29
# Read a new frame:  True
# 30
# Read a new frame:  True
# 31
# Read a new frame:  True
# 32
# Read a new frame:  True
# 33
# Read a new frame:  True
# 34
# Read a new frame:  True
# 35
# Read a new frame:  True
# 36
# Read a new frame:  True
# 37
# Read a new frame:  True
# 38
# Read a new frame:  True
# 39
# Read a new frame:  True
# 40
# Read a new frame:  True
# 41
# Read a new frame:  True
# 42
# Read a new frame:  True
# 43
# Read a new frame:  True
# 44
# Read a new frame:  True
# 45
# Read a new frame:  True
# 46
# Read a new frame:  True
# 47
# Read a new frame:  True
# 48
# Read a new frame:  True
# 49
# Read a new frame:  True
# 50
# Read a new frame:  True
# 51
# Read a new frame:  True
# 52
# Read a new frame:  True
# 53
# Read a new frame:  True
# 54
# Read a new frame:  True
# 55
# Read a new frame:  True
# 56
# Read a new frame:  True
# 57
# Read a new frame:  True
# 58
# Read a new frame:  True
# 59
# Read a new frame:  True
# 60
# Read a new frame:  True
# 61
# Read a new frame:  True
# 62
# Read a new frame:  True
# 63
# Read a new frame:  True
# 64
# Read a new frame:  True
# 65
# Read a new frame:  True
# 66
# Read a new frame:  True
# 67
# Read a new frame:  True
# 68
# Read a new frame:  True
# 69
# Read a new frame:  True
# 70
# Read a new frame:  True
# 71
# Read a new frame:  True
# 72
# Read a new frame:  True
# 73
# Read a new frame:  True
# 74
# Read a new frame:  True
# 75
# Read a new frame:  True
# 76
# Read a new frame:  True
# 77
# Read a new frame:  True
# 78
# Read a new frame:  True
# 79
# Read a new frame:  True
# 80
# Read a new frame:  True
# 81
# Read a new frame:  True
# 82
# Read a new frame:  True
# 83
# Read a new frame:  True
# 84
# Read a new frame:  True
# 85
# Read a new frame:  True
# 86
# Read a new frame:  True
# 87
# Read a new frame:  True
# 88
# Read a new frame:  True
# 89
# Read a new frame:  True
# 90
# Read a new frame:  True
# 91
# Read a new frame:  True
# 92
# Read a new frame:  True
# 93
# Read a new frame:  True
# 94
# Read a new frame:  True
# 95
# Read a new frame:  True
# 96
# Read a new frame:  True
# 97
# Read a new frame:  True
# 98
# Read a new frame:  True
# 99
# Read a new frame:  True
# 100
# Read a new frame:  True
# 101
# Read a new frame:  True
# 102
# Read a new frame:  True
# 103
# Read a new frame:  True
# 104
# Read a new frame:  True
# 105
# Read a new frame:  True
# 106
# Read a new frame:  True
# 107
# Read a new frame:  True
# 108
# Read a new frame:  True
# 109
# Read a new frame:  True
# 110
# Read a new frame:  True
# 111
# Read a new frame:  True
# 112
# Read a new frame:  True
# 113
# Read a new frame:  True
# 114
# Read a new frame:  True
# 115
# Read a new frame:  True
# 116
# Read a new frame:  True
# 117
# Read a new frame:  True
# 118
# Read a new frame:  True
# 119
# Read a new frame:  True
# 120
# Read a new frame:  True
# 121
# Read a new frame:  True
# 122
# Read a new frame:  True
# 123
# Read a new frame:  True
# 124
# Read a new frame:  True
# 125
# Read a new frame:  True
# 126
# Read a new frame:  True
# 127
# Read a new frame:  True
# 128
# Read a new frame:  True
# 129
# Read a new frame:  True
# 130
# Read a new frame:  True
# 131
# Read a new frame:  True
# 132
# Read a new frame:  True
# 133
# Read a new frame:  True
# 134
# Read a new frame:  True
# 135
# Read a new frame:  True
# 136
# Read a new frame:  True
# 137
# Read a new frame:  True
# 138
# Read a new frame:  True
# 139
# Read a new frame:  True
# 140
# Read a new frame:  True
# 141
# Read a new frame:  True
# 142
# Read a new frame:  True
# 143
# Read a new frame:  True
# 144
# Read a new frame:  True
# 145
# Read a new frame:  True
# 146
# Read a new frame:  True
# 147
# Read a new frame:  True
# 148
# Read a new frame:  True
# 149
# Read a new frame:  True
# 150
# Read a new frame:  True
# 151
# Read a new frame:  True
# 152
# Read a new frame:  True
# 153
# Read a new frame:  True
# 154
# Read a new frame:  True
# 155
# Read a new frame:  True
# 156
# Read a new frame:  True
# 157
# Read a new frame:  True
# 158
# Read a new frame:  True
# 159
# Read a new frame:  True
# 160
# Read a new frame:  True
# 161
# Read a new frame:  True
# 162
# Read a new frame:  True
# 163
# Read a new frame:  True
# 164
# Read a new frame:  True
# 165
# Read a new frame:  True
# 166
# Read a new frame:  True
# 167
# Read a new frame:  True
# 168
# Read a new frame:  True
# 169
# Read a new frame:  True
# 170
# Read a new frame:  True
# 171
# Read a new frame:  True
# 172
# Read a new frame:  True
# 173
# Read a new frame:  True
# 174
# Read a new frame:  True
# 175
# Read a new frame:  True
# 176
# Read a new frame:  True
# 177
# Read a new frame:  True
# 178
# Read a new frame:  True
# 179
# Read a new frame:  True
# 180
# Read a new frame:  True
# 181
# Read a new frame:  True
# 182
# Read a new frame:  True
# 183
# Read a new frame:  True
# 184
# Read a new frame:  True
# 185
# Read a new frame:  True
# 186
# Read a new frame:  True
# 187
# Read a new frame:  True
# 188
# Read a new frame:  True
# 189
# Read a new frame:  True
# 190
# Read a new frame:  True
# 191
# Read a new frame:  True
# 192
# Read a new frame:  True
# 193
# Read a new frame:  True
# 194
# Read a new frame:  True
# 195
# Read a new frame:  True
# 196
# Read a new frame:  True
# 197
# Read a new frame:  True
# 198
# Read a new frame:  True
# 199
# Read a new frame:  True
# 200
# Read a new frame:  True
# 201
# Read a new frame:  True
# 202
# Read a new frame:  True
# 203
# Read a new frame:  True
# 204
# Read a new frame:  True
# 205
# Read a new frame:  True
# 206
# Read a new frame:  True
# 207
# Read a new frame:  True
# 208
# Read a new frame:  True
# 209
# Read a new frame:  True
# 210
# Read a new frame:  True
# 211
# Read a new frame:  True
# 212
# Read a new frame:  True
# 213
# Read a new frame:  True
# 214
# Read a new frame:  True
# 215
# Read a new frame:  True
# 216
# Read a new frame:  True
# 217
# Read a new frame:  True
# 218
# Read a new frame:  True
# 219
# Read a new frame:  True
# 220
# Read a new frame:  True
# 221
# Read a new frame:  True
# 222
# Read a new frame:  True
# 223
# Read a new frame:  True
# 224
# Read a new frame:  True
# 225
# Read a new frame:  True
# 226
# Read a new frame:  True
# 227
# Read a new frame:  True
# 228
# Read a new frame:  True
# 229
# Read a new frame:  True
# 230
# Read a new frame:  True
# 231
# Read a new frame:  True
# 232
# Read a new frame:  True
# 233
# Read a new frame:  True
# 234
# Read a new frame:  True
# 235
# Read a new frame:  True
# 236
# Read a new frame:  True
# 237
# Read a new frame:  True
# 238
# Read a new frame:  True
# 239
# Read a new frame:  True
# 240
# Read a new frame:  True
# 241
# Read a new frame:  True
# 242
# Read a new frame:  True
# 243
# Read a new frame:  True
# 244
# Read a new frame:  True
# 245
# Read a new frame:  True
# 246
# Read a new frame:  True
# 247
# Read a new frame:  True
# 248
# Read a new frame:  True
# 249
# Read a new frame:  True
# 250
# Read a new frame:  True
# 251
# Read a new frame:  True
# 252
# Read a new frame:  True
# 253
# Read a new frame:  True
# 254
# Read a new frame:  True
# 255
# Read a new frame:  True
# 256
# Read a new frame:  True
# 257
# Read a new frame:  True
# 258
# Read a new frame:  True
# 259
# Read a new frame:  True
# 260
# Read a new frame:  True
# 261
# Read a new frame:  True
# 262
# Read a new frame:  True
# 263
# Read a new frame:  True
# 264
# Read a new frame:  True
# 265
# Read a new frame:  True
# 266
# Read a new frame:  True
# 267
# Read a new frame:  True
# 268
# Read a new frame:  True
# 269
# Read a new frame:  True
# 270
# Read a new frame:  True
# 271
# Read a new frame:  True
# 272
# Read a new frame:  True
# 273
# Read a new frame:  True
# 274
# Read a new frame:  True
# 275
# Read a new frame:  True
# 276
# Read a new frame:  True
# 277
# Read a new frame:  True
# 278
# Read a new frame:  True
# 279
# Read a new frame:  True
# 280
# Read a new frame:  True
# 281
# Read a new frame:  True
# 282
# Read a new frame:  True
# 283
# Read a new frame:  True
# 284
# Read a new frame:  True
# 285
# Read a new frame:  True
# 286
# Read a new frame:  True
# 287
# Read a new frame:  True
# 288
# Read a new frame:  True
# 289
# Read a new frame:  True
# 290
# Read a new frame:  True
# 291
# Read a new frame:  True
# 292
# Read a new frame:  True
# 293
# Read a new frame:  True
# 294
# Read a new frame:  True
# 295
# Read a new frame:  True
# 296
# Read a new frame:  True
# 297
# Read a new frame:  True
# 298
# Read a new frame:  True
# 299
# Read a new frame:  True
# 300
# Read a new frame:  True
# 301
# Read a new frame:  True
# 302
# Read a new frame:  True
# 303
# Read a new frame:  True
# 304
# Read a new frame:  True
# 305
# Read a new frame:  True
# 306
# Read a new frame:  True
# 307
# Read a new frame:  True
# 308
# Read a new frame:  True
# 309
# Read a new frame:  True
# 310
# Read a new frame:  True
# 311
# Read a new frame:  True
# 312
# Read a new frame:  True
# 313
# Read a new frame:  True
# 314
# Read a new frame:  True
# 315
# Read a new frame:  True
# 316
# Read a new frame:  True
# 317
# Read a new frame:  True
# 318
# Read a new frame:  True
# 319
# Read a new frame:  True
# 320
# Read a new frame:  True
# 321
# Read a new frame:  True
# 322
# Read a new frame:  True
# 323
# Read a new frame:  True
# 324
# Read a new frame:  True
# 325
# Read a new frame:  True
# 326
# Read a new frame:  True
# 327
# Read a new frame:  True
# 328
# Read a new frame:  True
# 329
# Read a new frame:  True
# 330
# Read a new frame:  True
# 331
# Read a new frame:  True
# 332
# Read a new frame:  True
# 333
# Read a new frame:  True
# 334
# Read a new frame:  True
# 335
# Read a new frame:  True
# 336
# Read a new frame:  True
# 337
# Read a new frame:  True
# 338
# Read a new frame:  True
# 339
# Read a new frame:  True
# 340
# Read a new frame:  True
# 341
# Read a new frame:  True
# 342
# Read a new frame:  True
# 343
# Read a new frame:  True
# 344
# Read a new frame:  True
# 345
# Read a new frame:  True
# 346
# Read a new frame:  True
# 347
# Read a new frame:  True
# 348
# Read a new frame:  True
# 349
# Read a new frame:  True
# 350
# Read a new frame:  True
# 351
# Read a new frame:  True
# 352
# Read a new frame:  True
# 353
# Read a new frame:  True
# 354
# Read a new frame:  True
# 355
# Read a new frame:  True
# 356
# Read a new frame:  True
# 357
# Read a new frame:  True
# 358
# Read a new frame:  True
# 359
# Read a new frame:  True
# 360
# Read a new frame:  True
# 361
# Read a new frame:  True
# 362
# Read a new frame:  True
# 363
# Read a new frame:  True
# 364
# Read a new frame:  True
# 365
# Read a new frame:  True
# 366
# Read a new frame:  True
# 367
# Read a new frame:  True
# 368
# Read a new frame:  True
# 369
# Read a new frame:  True
# 370
# Read a new frame:  True
# 371
# Read a new frame:  True
# 372
# Read a new frame:  True
# 373
# Read a new frame:  True
# 374
# Read a new frame:  True
# 375
# Read a new frame:  True
# 376
# Read a new frame:  True
# 377
# Read a new frame:  True
# 378
# Read a new frame:  True
# 379
# Read a new frame:  True
# 380
# Read a new frame:  True
# 381
# Read a new frame:  True
# 382
# Read a new frame:  False
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-31-5ac8b8e36b29> in <module>()
#       6     success,image = vidcap.read()
#       7     print ('Read a new frame: ', success)
# ----> 8     cv2.imwrite(vid_path+"frame25_%d.jpg" % count, image)     # save frame as JPEG file
#       9     count += 1
#      10     print(count)
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgcodecs/src/loadsave.cpp:715: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'
